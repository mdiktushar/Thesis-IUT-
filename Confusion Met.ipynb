# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
array = [[239.1428571, 1.42857142, 1.714285714, 1.428571429, 0.428571429, 5.857142857],
[0, 248.2857143, 0.142857143, 0.428571429, 0.857142857, 0.285714286], 
[2.571428571, 2.142857143, 217.1428571, 2.857142857, 0.428571429, 3.857142857],
[2.285714286, 8.714285714, 3, 232.2857143, 0, 3.714285714],
[2.285714286, 7.714285714, 2.857142857, 0.428571429, 231, 5.714285714],
[4, 2.285714286, 2.285714286, 2, 3.714285714, 234.2857143]
]

# %%
df_cm = pd.DataFrame(array, range(6), range(6))
plt.figure(figsize=(10,7))
sn.set(font_scale=1.7) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 10}) # font size

# plt.show()
# Out:
# <AxesSubplot:>

# %%
from sklearn import svm

# %%
svm()
